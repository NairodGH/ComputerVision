# %%
from ultralytics import YOLO

# %%
model = YOLO('yolov8n-seg.pt') # then runs/pose/train*id*/weights/last.pt to start from existing
model.train(data='config.yaml', epochs=30, imgsz=640)

# %%
model = YOLO('best.pt')
model.val()
model.predict(source='test.png', save=True)

# %%
model = YOLO('best.pt')
model.export(format='ncnn')
