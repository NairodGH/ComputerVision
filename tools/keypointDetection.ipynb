# %%
from ultralytics import YOLO

# %%
model = YOLO('runs/pose/train/weights/last.pt')
model.train(data='config.yaml', epochs=15, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.226 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.222  Python-3.12.4 torch-2.9.0+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=config.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=15, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=runs/pose/train/weights/last.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Nairod\Documents\GitHub\keypoint detection\runs\pose\train2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    823939  ultralytics.nn.modules.head.Pose             [1, [8, 2], [64, 128, 256]]
# YOLOv8n-pose summary: 144 layers, 3,083,475 parameters, 3,083,459 gradients, 8.4 GFLOPs
#
# Transferred 397/397 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.0 ms, read: 490.2268.4 MB/s, size: 355.4 KB)
# train: Scanning C:\Users\Nairod\Documents\GitHub\keypoint detection\labels\train... 338 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 338/338 390.1it/s 0.9s0.1s
# train: New cache created: C:\Users\Nairod\Documents\GitHub\keypoint detection\labels\train.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 802.2119.8 MB/s, size: 393.8 KB)
# val: Scanning C:\Users\Nairod\Documents\GitHub\keypoint detection\labels\val... 152 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 152/152 438.8it/s 0.3s0.1s
# val: New cache created: C:\Users\Nairod\Documents\GitHub\keypoint detection\labels\val.cache
# Plotting labels to C:\Users\Nairod\Documents\GitHub\keypoint detection\runs\pose\train2\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 63 weight(decay=0.0), 73 weight(decay=0.0005), 72 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\Nairod\Documents\GitHub\keypoint detection\runs\pose\train2
# Starting training for 15 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        1/15         0G     0.7794      5.373          0     0.5436      1.021          3        640: 100% ━━━━━━━━━━━━ 22/22 0.1it/s 3:393.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.2it/s 30.3s8.2ss
#                    all        152        152      0.973      0.967      0.989      0.829      0.152      0.125      0.109      0.015
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        2/15         0G     0.8251      5.243          0     0.5633      1.009          2        640: 100% ━━━━━━━━━━━━ 22/22 0.1it/s 3:374.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.2it/s 25.9s7.2ss
#                    all        152        152      0.985      0.961      0.991      0.783      0.316      0.145       0.13     0.0286
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss   dfl_loss  Instances       Size
#        3/15         0G     0.7851      4.963          0     0.5472     0.9882         22        640: 14% ━╸────────── 3/22 0.3it/s 24.3s<57.3s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 model = YOLO('runs/pose/train/weights/last.pt')
# ----> 2 model.train(data='config.yaml', epochs=15, imgsz=640)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\model.py:800, in Model.train(self, trainer, **kwargs)
#     797     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     798     self.model = self.trainer.model
# --> 800 self.trainer.train()
#     801 # Update model and cfg after training
#     802 if RANK in {-1, 0}:
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py:240, in BaseTrainer.train(self)
#     237         ddp_cleanup(self, str(file))
#     239 else:
# --> 240     self._do_train()
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\engine\trainer.py:424, in BaseTrainer._do_train(self)
#     422     loss, self.loss_items = unwrap_model(self.model).loss(batch, preds)
#     423 else:
# --> 424     loss, self.loss_items = self.model(batch)
#     425 self.loss = loss.sum()
#     426 if RANK != -1:
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:138, in BaseModel.forward(self, x, *args, **kwargs)
#     124 """
#     125 Perform forward pass of the model for either training or inference.
#     126
#    (...)    135     (torch.Tensor): Loss if x is a dict (training), or network predictions (inference).
#     136 """
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
# --> 138     return self.loss(x, *args, **kwargs)
#     139 return self.predict(x, *args, **kwargs)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:338, in BaseModel.loss(self, batch, preds)
#     335     self.criterion = self.init_criterion()
#     337 if preds is None:
# --> 338     preds = self.forward(batch["img"])
#     339 return self.criterion(preds, batch)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:139, in BaseModel.forward(self, x, *args, **kwargs)
#     137 if isinstance(x, dict):  # for cases of training and validating while training.
#     138     return self.loss(x, *args, **kwargs)
# --> 139 return self.predict(x, *args, **kwargs)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:157, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     155 if augment:
#     156     return self._predict_augment(x)
# --> 157 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\tasks.py:180, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     178 if profile:
#     179     self._profile_one_layer(m, x, dt)
# --> 180 x = m(x)  # run
#     181 y.append(x if m.i in self.save else None)  # save output
#     182 if visualize:
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\modules\block.py:318, in C2f.forward(self, x)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\modules\block.py:318, in <genexpr>(.0)
#     316 """Forward pass through C2f layer."""
#     317 y = list(self.cv1(x).chunk(2, 1))
# --> 318 y.extend(m(y[-1]) for m in self.m)
#     319 return self.cv2(torch.cat(y, 1))
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\modules\block.py:495, in Bottleneck.forward(self, x)
#     493 def forward(self, x: torch.Tensor) -> torch.Tensor:
#     494     """Apply bottleneck with optional shortcut connection."""
# --> 495     return x + self.cv2(self.cv1(x)) if self.add else self.cv2(self.cv1(x))
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\nn\modules\conv.py:81, in Conv.forward(self, x)
#      71 def forward(self, x):
#      72     """
#      73     Apply convolution, batch normalization and activation to input tensor.
#      74
#    (...)     79         (torch.Tensor): Output tensor.
#      80     """
# ---> 81     return self.act(self.bn(self.conv(x)))
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\activation.py:473, in SiLU.forward(self, input)
#     469 def forward(self, input: Tensor) -> Tensor:
#     470     """
#     471     Runs the forward pass.
#     472     """
# --> 473     return F.silu(input, inplace=self.inplace)
#
# File c:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\functional.py:2370, in silu(input, inplace)
#    2368     return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2369 if inplace:
# -> 2370     return torch._C._nn.silu_(input)
#    2371 return torch._C._nn.silu(input)
#
# KeyboardInterrupt:

# %%
model = YOLO('best.pt')
model.val()
model.predict(source='test.png', save=True)
# Out:
# Ultralytics 8.3.222  Python-3.12.4 torch-2.9.0+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# YOLOv8n-pose summary (fused): 81 layers, 3,078,179 parameters, 0 gradients, 8.3 GFLOPs
# val: Fast image access  (ping: 0.30.2 ms, read: 187.846.7 MB/s, size: 412.5 KB)
# val: Scanning C:\Users\Nairod\Documents\GitHub\keypoint detection\labels\val.cache... 152 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 152/152 149.6Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 10/10 0.3it/s 32.0s.3ss
#                    all        152        152      0.987      0.979      0.993      0.843      0.613      0.605      0.593      0.309
# Speed: 4.6ms preprocess, 177.0ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to C:\Users\Nairod\Documents\GitHub\keypoint detection\runs\pose\val2
#
# image 1/1 c:\Users\Nairod\Documents\GitHub\keypoint detection\test.png: 480x640 1 enderman, 135.4ms
# Speed: 1.8ms preprocess, 135.4ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to C:\Users\Nairod\Documents\GitHub\keypoint detection\runs\pose\predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: ultralytics.engine.results.Keypoints object
#  masks: None
#  names: {0: 'enderman'}
#  obb: None
#  orig_img: array([[[112, 145, 178],
#          [113, 146, 179],
#          [114, 149, 182],
#          ...,
#          [ 60,  79, 122],
#          [ 58,  78, 119],
#          [ 58,  78, 119]],
#
#         [[112, 145, 178],
#          [113, 146, 179],
#          [114, 149, 182],
#          ...,
#          [ 59,  78, 121],
#          [ 59,  79, 120],
#          [ 58,  78, 119]],
#
#         [[113, 143, 178],
#          [116, 146, 181],
#          [114, 150, 180],
#          ...,
#          [ 60,  75, 125],
#          [ 61,  77, 123],
#          [ 60,  76, 122]],
#
#         ...,
#
#         [[113, 148, 192],
#          [111, 146, 190],
#          [108, 146, 188],
#          ...,
#          [ 55,  76, 108],
#          [ 56,  78, 106],
#          [ 56,  78, 106]],
#
#         [[106, 146, 192],
#          [103, 143, 189],
#          [104, 142, 190],
#          ...,
#          [ 57,  80, 112],
#          [ 59,  80, 111],
#          [ 58,  79, 110]],
#
#         [[104, 144, 190],
#          [102, 142, 188],
#          [102, 140, 188],
#          ...,
#          [ 58,  81, 113],
#          [ 59,  80, 111],
#          [ 57,  78, 109]]], shape=(480, 640, 3), dtype=uint8)
#  orig_shape: (480, 640)
#  path: 'c:\\Users\\Nairod\\Documents\\GitHub\\keypoint detection\\test.png'
#  probs: None
#  save_dir: 'C:\\Users\\Nairod\\Documents\\GitHub\\keypoint detection\\runs\\pose\\predict2'
#  speed: {'preprocess': 1.797400000214111, 'inference': 135.39850000233855, 'postprocess': 3.799599999183556}]

# %%
model = YOLO('best.pt')
model.export(format='ncnn')
# Out:
# Ultralytics 8.3.222  Python-3.12.4 torch-2.9.0+cpu CPU (11th Gen Intel Core i5-11400H @ 2.70GHz)
# YOLOv8n-pose summary (fused): 81 layers, 3,078,179 parameters, 0 gradients, 8.3 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 21, 8400) (6.1 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.72...
# ONNX: export success  2.7s, saved as 'best.onnx' (12.1 MB)
#
# NCNN: starting export with NCNN 1.0.20250916...
# NCNN: running 'C:\Users\Nairod\AppData\Local\Programs\Python\Python312\Lib\site-packages\ultralytics\pnnx.exe best.onnx ncnnparam=best_ncnn_model\model.ncnn.param ncnnbin=best_ncnn_model\model.ncnn.bin ncnnpy=best_ncnn_model\model_ncnn.py pnnxparam=best_ncnn_model\model.pnnx.param pnnxbin=best_ncnn_model\model.pnnx.bin pnnxpy=best_ncnn_model\model_pnnx.py pnnxonnx=best_ncnn_model\model.pnnx.onnx fp16=0 device=cpu inputshape="[1, 3, 640, 640]"'
# NCNN: export success  1.4s, saved as 'best_ncnn_model' (12.0 MB)
#
# Export complete (4.4s)
# Results saved to C:\Users\Nairod\Documents\GitHub\keypoint detection
# Predict:         yolo predict task=pose model=best_ncnn_model imgsz=640
# Validate:        yolo val task=pose model=best_ncnn_model imgsz=640 data=config.yaml
# Visualize:       https://netron.app
# 'best_ncnn_model'
